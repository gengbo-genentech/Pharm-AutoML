# %%
import os
cwd = os.getcwd()
print (cwd)
import pandas as pd
import numpy as np
# set up pharmAutoML by "python setup.py install"
from pharmAutoML import autoML_pipeline
import json
# Out:
# /Users/liug28/Downloads/Pharm-AutoML

# %%
result_path="./automl_result"
data_dir="./data/risk_factors_cervical_cancer.csv"
target = 'Biopsy'
def load_data(csv_path, target):
    allData=pd.read_csv(csv_path)
    y = allData[target]
    x = allData.drop([target], axis=1)
    return x, y

x, y = load_data(data_dir, target)
para = open('./PharmAutoML/default_parameters.json')
parameter = json.load(para)
# if user want to change parameters, they can change it from here
# parameter['classifier_parameters']['clfs']={'XGboost':{}}
print (parameter)
# Out:
# {'preprocessing_parameters': {'drop_features': [None], 'missing_threshold_rows': [0.2], 'missing_threshold_columns': [0.2], 'correlation_threshold': [0.98]}, 'imputation_parameters': {'categorical_features': [None], 'check_diff_categorical_threshold': [0.1], 'impute_category_strategy': ['most_frequent'], 'impute_numerical_strategy': ['mean'], 'add_nan_label': [False]}, 'feature_selection_parameters': {'feature_selection_method': ['shapRFEcv']}, 'train_test_split_parameters': {'tts_random_seed': [0], 'test_size': [0.2]}, 'classifier_parameters': {'PCA': [False], 'PCA_feature_num': [0], 'clfs': {'LRC': {}, 'SVC': {}, 'KNN': {}, 'RF': {}, 'ET': {}, 'GB': {}, 'SGD': {}, 'AB': {}, 'XGboost': {}}, 'n_fold': [5], 'n_repeats': [None], 'useDropColFeaImport': [False]}}

# %%
aml=autoML_pipeline.PharmAutoML(x,y)
result_imputeMissing = aml.AutoML(result_path, impute_missing_mode = True, tuning_mode = True, loss_function = 'roc_auc', parameter = parameter)
# Out:
# parameter
# {'preprocessing_parameters': {'drop_features': [[None]], 'missing_threshold_rows': [0.2], 'missing_threshold_columns': [0.2], 'correlation_threshold': [0.98]}, 'imputation_parameters': {'categorical_features': [[None]], 'check_diff_categorical_threshold': [0.1], 'impute_category_strategy': ['most_frequent'], 'impute_numerical_strategy': ['mean'], 'add_nan_label': [False]}, 'feature_selection_parameters': {'feature_selection_method': ['shapRFEcv']}, 'train_test_split_parameters': {'tts_random_seed': [0], 'test_size': [0.2]}, 'classifier_parameters': {'PCA': [False], 'PCA_feature_num': [0], 'clfs': [{'AB': {}}, {'ET': {}}, {'GB': {}}, {'KNN': {}}, {'LRC': {}}, {'RF': {}}, {'SGD': {}}, {'SVC': {}}, {'XGboost': {}}], 'n_fold': [5], 'n_repeats': [None], 'useDropColFeaImport': [False]}}
# parameter_grid
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'AB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'ET': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'GB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'KNN': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'LRC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'RF': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SGD': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SVC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'XGboost': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
#
#
# INFO: './automl_result' does not exist. Creating a new experiment
# ########################################
# TUNING MODEL: the parameter of index  0 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'AB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:01<00:00,  1.05s/trial, best loss: -0.8032626288440242]
#
# 100%|##########| 1/1 [00:01<00:00,  1.06s/trial, best loss: -0.8032626288440242]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:00<00:00,  1.12trial/s, best loss: -0.8032626288440242]
#
# 100%|##########| 2/2 [00:00<00:00,  2.23trial/s, best loss: -0.8032626288440242]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00,  6.87trial/s, best loss: -0.920798194054008]
#
# 100%|##########| 3/3 [00:00<00:00, 19.74trial/s, best loss: -0.920798194054008]
# AdaBoostClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.1189275235247596, 'accuracy_cv_mean': 0.9551239669421487, 'roc_auc_cv_mean': 0.921975546975547, 'f1_cv_mean': 0.7369281045751634, 'average_precision_cv_mean': 0.5766467118739846, 'precision_cv_mean': 0.6386324786324786, 'recall_cv_mean': 0.8833333333333333}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.04178651836891703, 'accuracy_cv_stdev': 0.01894293730940708, 'roc_auc_cv_stdev': 0.06905653533942581, 'f1_cv_stdev': 0.09663499048066883, 'average_precision_cv_stdev': 0.12683429261225057, 'precision_cv_stdev': 0.10533195459557002, 'recall_cv_stdev': 0.13629522694830107}
# best_model
# {'learner': AdaBoostClassifier(learning_rate=0.022760652309917605, n_estimators=18,
#                    random_state=0), 'preprocs': (StandardScaler(with_mean=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [01:01<00:00, 61.12s/trial, best loss: -0.921975546975547]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'AB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': AdaBoostClassifier(learning_rate=0.022760652309917605, n_estimators=18,
#                    random_state=0), 'preprocs': (StandardScaler(with_mean=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  1 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'ET': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:00<00:00,  8.15trial/s, best loss: -0.6026705852287247]
#
# 100%|##########| 1/1 [00:00<00:00,  7.74trial/s, best loss: -0.6026705852287247]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:14<00:00, 14.32s/trial, best loss: -0.8336101882613509]
#
# 100%|##########| 2/2 [00:14<00:00,  7.16s/trial, best loss: -0.8336101882613509]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00,  2.64trial/s, best loss: -0.8978831246273108]
#
# 100%|##########| 3/3 [00:00<00:00,  7.79trial/s, best loss: -0.8978831246273108]
# ExtraTreesClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.11560430696815516, 'accuracy_cv_mean': 0.9551239669421487, 'roc_auc_cv_mean': 0.9510840081152582, 'f1_cv_mean': 0.7369281045751634, 'average_precision_cv_mean': 0.758187246454122, 'precision_cv_mean': 0.6386324786324786, 'recall_cv_mean': 0.8833333333333333}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.04002874512489987, 'accuracy_cv_stdev': 0.01894293730940708, 'roc_auc_cv_stdev': 0.07130339451766364, 'f1_cv_stdev': 0.09663499048066883, 'average_precision_cv_stdev': 0.1249180355865794, 'precision_cv_stdev': 0.10533195459557002, 'recall_cv_stdev': 0.13629522694830107}
# best_model
# {'learner': ExtraTreesClassifier(bootstrap=True, criterion='entropy', max_depth=2,
#                      max_features=0.7930015274954807, min_samples_leaf=2,
#                      n_estimators=67, n_jobs=1, random_state=0, verbose=False), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [01:02<00:00, 62.56s/trial, best loss: -0.9510840081152582]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'ET': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': ExtraTreesClassifier(bootstrap=True, criterion='entropy', max_depth=2,
#                      max_features=0.7930015274954807, min_samples_leaf=2,
#                      n_estimators=67, n_jobs=1, random_state=0, verbose=False), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  2 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'GB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:03<00:00,  3.14s/trial, best loss: -0.5]
#
# 100%|##########| 1/1 [00:03<00:00,  3.14s/trial, best loss: -0.5]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:06<00:00,  6.77s/trial, best loss: -0.7354118749467586]
#
# 100%|##########| 2/2 [00:06<00:00,  3.39s/trial, best loss: -0.7354118749467586]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00,  1.17trial/s, best loss: -0.7354118749467586]
#
# 100%|##########| 3/3 [00:00<00:00,  3.48trial/s, best loss: -0.7354118749467586]
# GradientBoostingClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.17159721180622192, 'accuracy_cv_mean': 0.9534435261707989, 'roc_auc_cv_mean': 0.9418683192120691, 'f1_cv_mean': 0.5340909090909091, 'average_precision_cv_mean': 0.7220101492717357, 'precision_cv_mean': 0.8642857142857143, 'recall_cv_mean': 0.43333333333333335}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.10750466322168659, 'accuracy_cv_stdev': 0.014957196832980838, 'roc_auc_cv_stdev': 0.08816791373454756, 'f1_cv_stdev': 0.21902064131563959, 'average_precision_cv_stdev': 0.1925724952911322, 'precision_cv_stdev': 0.13458174058154837, 'recall_cv_stdev': 0.23761774209436612}
# best_model
# {'learner': GradientBoostingClassifier(learning_rate=0.003590114964235196,
#                            loss='exponential', max_depth=None,
#                            max_features='sqrt', n_estimators=570,
#                            random_state=0, subsample=0.6550109287073544), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [01:54<00:00, 114.80s/trial, best loss: -0.9418683192120691]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'GB': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': GradientBoostingClassifier(learning_rate=0.003590114964235196,
#                            loss='exponential', max_depth=None,
#                            max_features='sqrt', n_estimators=570,
#                            random_state=0, subsample=0.6550109287073544), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  3 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'KNN': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:00<00:00, 26.35trial/s, best loss: -0.627374563421075]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:00<00:00, 51.14trial/s, best loss: -0.627374563421075]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00, 77.99trial/s, best loss: -0.6651546128290315]
# KNeighborsClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -2.412501167613403, 'accuracy_cv_mean': 0.9301515151515152, 'roc_auc_cv_mean': 0.6671305233805234, 'f1_cv_mean': 0.3833638583638584, 'average_precision_cv_mean': 0.24222942811957965, 'precision_cv_mean': 0.4161111111111111, 'recall_cv_mean': 0.3611111111111111}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.5135394668513481, 'accuracy_cv_stdev': 0.014868570212541926, 'roc_auc_cv_stdev': 0.12260335169739484, 'f1_cv_stdev': 0.24636140191357722, 'average_precision_cv_stdev': 0.1386231791671666, 'precision_cv_stdev': 0.24674110488426157, 'recall_cv_stdev': 0.2501928268701642}
# best_model
# {'learner': KNeighborsClassifier(metric='euclidean', n_jobs=1, n_neighbors=1,
#                      weights='distance'), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [00:44<00:00, 44.60s/trial, best loss: -0.6671305233805234]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'KNN': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': KNeighborsClassifier(metric='euclidean', n_jobs=1, n_neighbors=1,
#                      weights='distance'), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  4 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'LRC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:00<00:00, 32.38trial/s, best loss: -0.5]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:00<00:00, 63.10trial/s, best loss: -0.9097878865320725]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00, 94.71trial/s, best loss: -0.920798194054008]
# LogisticRegression
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.2431560705454238, 'accuracy_cv_mean': 0.9551239669421487, 'roc_auc_cv_mean': 0.9313789235664236, 'f1_cv_mean': 0.7369281045751634, 'average_precision_cv_mean': 0.5853621669028646, 'precision_cv_mean': 0.6386324786324786, 'recall_cv_mean': 0.8833333333333333}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.02302236016207097, 'accuracy_cv_stdev': 0.01894293730940708, 'roc_auc_cv_stdev': 0.05892512552512465, 'f1_cv_stdev': 0.09663499048066883, 'average_precision_cv_stdev': 0.09694858704750253, 'precision_cv_stdev': 0.10533195459557002, 'recall_cv_stdev': 0.13629522694830107}
# best_model
# {'learner': LogisticRegression(C=0.7777691418203918, intercept_scaling=0.15842660999211708,
#                    random_state=0, solver='liblinear',
#                    tol=0.002277500296928366), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [00:45<00:00, 45.22s/trial, best loss: -0.9313789235664236]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'LRC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': LogisticRegression(C=0.7777691418203918, intercept_scaling=0.15842660999211708,
#                    random_state=0, solver='liblinear',
#                    tol=0.002277500296928366), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  5 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'RF': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:00<00:00,  4.30trial/s, best loss: -0.8464094045489395]
#
# 100%|##########| 1/1 [00:00<00:00,  4.13trial/s, best loss: -0.8464094045489395]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:00<00:00,  2.41trial/s, best loss: -0.8464094045489395]
#
# 100%|##########| 2/2 [00:00<00:00,  4.74trial/s, best loss: -0.8464094045489395]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00,  2.49trial/s, best loss: -0.8464094045489395]
#
# 100%|##########| 3/3 [00:00<00:00,  7.32trial/s, best loss: -0.8464094045489395]
# RandomForestClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.801107164029655, 'accuracy_cv_mean': 0.9518044077134986, 'roc_auc_cv_mean': 0.9014081045331045, 'f1_cv_mean': 0.6293650793650793, 'average_precision_cv_mean': 0.6136290210911423, 'precision_cv_mean': 0.6484126984126984, 'recall_cv_mean': 0.625}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.43766376771196586, 'accuracy_cv_stdev': 0.020459669521711993, 'roc_auc_cv_stdev': 0.11548924679674158, 'f1_cv_stdev': 0.1984047617460254, 'average_precision_cv_stdev': 0.17817212112533992, 'precision_cv_stdev': 0.1544726641864236, 'recall_cv_stdev': 0.23282020297555847}
# best_model
# {'learner': RandomForestClassifier(bootstrap=False, criterion='entropy',
#                        max_features=0.9562882456244782, n_estimators=40,
#                        n_jobs=1, random_state=0, verbose=False), 'preprocs': (StandardScaler(with_mean=False, with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [00:47<00:00, 47.62s/trial, best loss: -0.9014081045331045]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'RF': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': RandomForestClassifier(bootstrap=False, criterion='entropy',
#                        max_features=0.9562882456244782, n_estimators=40,
#                        n_jobs=1, random_state=0, verbose=False), 'preprocs': (StandardScaler(with_mean=False, with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  6 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SGD': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:00<00:00, 24.41trial/s, best loss: -0.7859911406423035]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:00<00:00, 47.05trial/s, best loss: -0.9172203765227022]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00, 74.81trial/s, best loss: -0.9172203765227022]
# SGDClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -1.4725931956921166, 'accuracy_cv_mean': 0.9551239669421487, 'roc_auc_cv_mean': 0.9375563063063063, 'f1_cv_mean': 0.7369281045751634, 'average_precision_cv_mean': 0.6104650860368945, 'precision_cv_mean': 0.6386324786324786, 'recall_cv_mean': 0.8833333333333333}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.6813187021443367, 'accuracy_cv_stdev': 0.01894293730940708, 'roc_auc_cv_stdev': 0.0603151265121698, 'f1_cv_stdev': 0.09663499048066883, 'average_precision_cv_stdev': 0.1108075001451837, 'precision_cv_stdev': 0.10533195459557002, 'recall_cv_stdev': 0.13629522694830107}
# best_model
# {'learner': SGDClassifier(alpha=0.08703328760667395, class_weight='balanced',
#               eta0=0.003622985263704631, l1_ratio=0.27712257990227496,
#               loss='modified_huber', max_iter=336164031.0, n_jobs=1,
#               penalty='l1', power_t=0.48570141641984765, random_state=0,
#               tol=0.006529434688817984, verbose=False), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [00:44<00:00, 44.55s/trial, best loss: -0.9375563063063063]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SGD': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': SGDClassifier(alpha=0.08703328760667395, class_weight='balanced',
#               eta0=0.003622985263704631, l1_ratio=0.27712257990227496,
#               loss='modified_huber', max_iter=336164031.0, n_jobs=1,
#               penalty='l1', power_t=0.48570141641984765, random_state=0,
#               tol=0.006529434688817984, verbose=False), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  7 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SVC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [03:49<00:00, 229.33s/trial, best loss: -0.7683789079137916]
#
# 100%|##########| 1/1 [03:49<00:00, 229.34s/trial, best loss: -0.7683789079137916]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [1:28:55<00:00, 5335.51s/trial, best loss: -0.920798194054008]
#
# 100%|##########| 2/2 [1:28:55<00:00, 2667.76s/trial, best loss: -0.920798194054008]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00, 40.06trial/s, best loss: -0.920798194054008]
# SVC
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.11513423342936019, 'accuracy_cv_mean': 0.9551239669421487, 'roc_auc_cv_mean': 0.930066226941227, 'f1_cv_mean': 0.7369281045751634, 'average_precision_cv_mean': 0.6670965886230583, 'precision_cv_mean': 0.6386324786324786, 'recall_cv_mean': 0.8833333333333333}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.050187713879193546, 'accuracy_cv_stdev': 0.01894293730940708, 'roc_auc_cv_stdev': 0.08259566411310884, 'f1_cv_stdev': 0.09663499048066883, 'average_precision_cv_stdev': 0.14790774980347796, 'precision_cv_stdev': 0.10533195459557002, 'recall_cv_stdev': 0.13629522694830107}
# best_model
# {'learner': SVC(C=2379.127045986855, cache_size=512, degree=1, gamma='auto',
#     kernel='linear', max_iter=724202204.0, probability=True, random_state=0,
#     shrinking=False, tol=0.00023337725333339528), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [12:23:22<00:00, 44602.04s/trial, best loss: -0.930066226941227]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'SVC': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': SVC(C=2379.127045986855, cache_size=512, degree=1, gamma='auto',
#     kernel='linear', max_iter=724202204.0, probability=True, random_state=0,
#     shrinking=False, tol=0.00023337725333339528), 'preprocs': (StandardScaler(with_std=False),), 'ex_preprocs': ()}
# ########################################
# TUNING MODEL: the parameter of index  8 is
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'XGboost': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': [None], 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': [None], 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# Preprocessing Step 1: Manually Drop Features
# manually drop 0 features.
# Preprocessing Step 2: Find Single Unique Features
# 2 features with a single unique value.
# Preprocessing Step 3: Find Missing
# 106 instances have more than 0.20 fraction of missing values.
# Preprocessing Step 3: Find Missing
# 2 features have more than 0.20 fraction of missing values.
# Preprocessing Step 4: Find Collinear Features by Pearson Correlations
# 1 features with a correlation magnitude greater than 0.98.
# Data Preprocessor Summary
# 6 total features out of 35 identified for removal.
# {'drop_features': [None], 'single_unique': ['STDs:cervical condylomatosis', 'STDs:AIDS'], 'missing_features': ['STDs: Time since first diagnosis', 'STDs: Time since last diagnosis'], 'collinear': ['STDs:vulvo-perineal condylomatosis']}
# 106 total instances out of 858 identified for removal.
# {'missing_instances': [71, 74, 90, 95, 98, 102, 111, 117, 141, 142, 143, 149, 164, 176, 178, 189, 193, 220, 225, 228, 234, 243, 256, 263, 267, 271, 272, 279, 281, 284, 299, 304, 307, 316, 319, 321, 323, 328, 330, 338, 341, 343, 345, 346, 350, 353, 381, 391, 398, 405, 408, 412, 417, 419, 436, 443, 445, 452, 453, 457, 460, 476, 489, 495, 505, 512, 525, 527, 528, 542, 544, 547, 551, 552, 564, 576, 586, 595, 603, 607, 619, 633, 696, 700, 701, 705, 732, 735, 741, 751, 757, 761, 762, 767, 769, 771, 772, 778, 783, 785, 788, 792, 794, 807, 814, 816]}
# the imputed numerical features include: Smokes (packs/year), Hormonal Contraceptives, Num of pregnancies, Hormonal Contraceptives (years), Smokes (years), IUD, Smokes, IUD (years), Number of sexual partners, First sexual intercourse
# data imputation summary
# {'categorical': [], 'numerical': ['Smokes (packs/year)', 'Hormonal Contraceptives', 'Num of pregnancies', 'Hormonal Contraceptives (years)', 'Smokes (years)', 'IUD', 'Smokes', 'IUD (years)', 'Number of sexual partners', 'First sexual intercourse']}
# the selected features by shapRFEcv are
# ['Schiller', 'First sexual intercourse', 'Age']
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 1/1 [00:01<00:00,  1.01s/trial, best loss: -0.8199165175909361]
#
# 100%|##########| 1/1 [00:01<00:00,  1.02s/trial, best loss: -0.8199165175909361]
#  50%|#####     | 1/2 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 2/2 [00:01<00:00,  1.07s/trial, best loss: -0.8199165175909361]
#
# 100%|##########| 2/2 [00:01<00:00,  1.86trial/s, best loss: -0.8199165175909361]
#  67%|######6   | 2/3 [00:00<?, ?trial/s, best loss=?]
#
# 100%|##########| 3/3 [00:00<00:00,  3.34trial/s, best loss: -0.8199165175909361]
#
# 100%|##########| 3/3 [00:00<00:00,  9.83trial/s, best loss: -0.8199165175909361]
# XGBClassifier
# mean value of different metrics are
# {'neg_log_loss_cv_mean': -0.17630073019995102, 'accuracy_cv_mean': 0.9517768595041323, 'roc_auc_cv_mean': 0.9475725725725725, 'f1_cv_mean': 0.6104901960784314, 'average_precision_cv_mean': 0.7010657166907167, 'precision_cv_mean': 0.6880952380952381, 'recall_cv_mean': 0.5805555555555556}
# std of different metrics are
# {'neg_log_loss_cv_stdev': 0.10755622715515709, 'accuracy_cv_stdev': 0.015873079464964666, 'roc_auc_cv_stdev': 0.06878586470542095, 'f1_cv_stdev': 0.175025263184454, 'average_precision_cv_stdev': 0.18407285404193652, 'precision_cv_stdev': 0.09676967886843128, 'recall_cv_stdev': 0.2170402761735284}
# best_model
# {'learner': XGBClassifier(colsample_bylevel=0.6049943703722438,
#               colsample_bytree=0.8089058373504634, gamma=0.005867511610152165,
#               learning_rate=0.35670950007657753, max_depth=6, missing=nan,
#               n_estimators=1800, reg_alpha=0.0011958694284566022,
#               reg_lambda=1.2236276966734878, seed=0,
#               subsample=0.9996041455772968), 'preprocs': (StandardScaler(),), 'ex_preprocs': ()}
# 100%|██████████| 1/1 [01:11<00:00, 71.14s/trial, best loss: -0.9475725725725725]
# the best model is :
# {'classifier_parameters': {'PCA': False, 'PCA_feature_num': 0, 'clfs': {'XGboost': {}}, 'n_fold': 5, 'n_repeats': None, 'useDropColFeaImport': False}, 'feature_selection_parameters': {'feature_selection_method': 'shapRFEcv'}, 'imputation_parameters': {'add_nan_label': False, 'categorical_features': (None,), 'check_diff_categorical_threshold': 0.1, 'impute_category_strategy': 'most_frequent', 'impute_numerical_strategy': 'mean'}, 'preprocessing_parameters': {'correlation_threshold': 0.98, 'drop_features': (None,), 'missing_threshold_columns': 0.2, 'missing_threshold_rows': 0.2}, 'train_test_split_parameters': {'test_size': 0.2, 'tts_random_seed': 0}}
# {'learner': XGBClassifier(colsample_bylevel=0.6049943703722438,
#               colsample_bytree=0.8089058373504634, gamma=0.005867511610152165,
#               learning_rate=0.35670950007657753, max_depth=6, missing=nan,
#               n_estimators=1800, reg_alpha=0.0011958694284566022,
#               reg_lambda=1.2236276966734878, seed=0,
#               subsample=0.9996041455772968), 'preprocs': (StandardScaler(),), 'ex_preprocs': ()}
